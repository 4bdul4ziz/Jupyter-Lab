# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.signal as scipySignal
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [1], in <module>
# ----> 1 import numpy as np
#       2 import matplotlib.pyplot as plt
#       3 import scipy.signal as scipySignal
#
# ModuleNotFoundError: No module named 'numpy'

# %%
import matplotlib.pyplot as plt

# %%
freq = 50 #hz
time_period = 1/freq
time=time_period*2
amplitude=2

# %%
t=np.linspace (0, time, 500, endpoint=True)
x=2*3.14*freq*t

# %%
yc=amplitude*np.sin(x)

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"]= (10,4)
fig = plt.figure()
fig.add_axes ([0.1,0.1,0.8,0.8])
plt.plot (x, yc, color ='tab:red', linewidth=3)
plt.xlabel ("time (ms)", fontsize=18)
plt.ylabel ("Amplitude", fontsize=18)
plt.title ("Abdul Aziz A.B - 20BRS1185, Signal plot", fontsize=18)
# Out:
# Text(0.5, 1.0, 'Abdul Aziz A.B - 20BRS1185, Signal plot')

# %%
yc=amplitude*np.sin(x) + 1*np.random.rand (len(x))

# %%
plt.rcParams ["figure.figsize"] = (10,4)
fig = plt.figure()
fig.add_axes([0.1,0.1,0.8,0.8])
x1=x*1000/(2*3.14*freq) #in ms
plt.plot(x1, yc, color ='tab:red', linewidth=3)
plt.xlabel("time (ms) ", fontsize=18)
plt.ylabel("Amplitude", fontsize=18)
plt.title("Abdul Aziz A.B - 20BRS1185, Signal plot with noise", fontsize=18)
#fig.set ylim([-3,3])
# Out:
# Text(0.5, 1.0, 'Abdul Aziz A.B - 20BRS1185, Signal plot with noise')

# %%
# Homework 9
# Signal corrupted by noise.
# x(t) = A1sin(2pif1t) + A2sin(2pif2t) + noise
# 1: Create a program that reads in the file and plots it as a function of time.
import matplotlib.pyplot as plt
import numpy as np

def read(txt):
    return_list = []
    for line in txt:
        return_list.append(float(line.strip()))
    return return_list

wave = open("waveform.txt", "r")
values = read(wave)
timeList = [t for t in range(len(values))] # for each item in the list, save 0:n
fs = 1500
ts = 1/fs
sample_length = len(values)

noisy = np.fft.fft(values)
half = int(sample_length/2)
p2 = np.abs(noisy / sample_length)
p1 = p2[:half]
p1[1:-2] = 2*p1[1:-2]

ps = int(fs/sample_length)
spectrum = [ps * idx for idx in range(half)]

# number 3
a1 = 0.96
f1 = 32
a2 = 1.37
f2 = 67

fixed_noise = np.fix([(x/.5).real for x in noisy])*.5
ifft_fcn = np.fft.ifft(fixed_noise)

plt.figure("1")
plt.title("Number 1")
plt.plot(timeList, values)

plt.figure("2")
plt.title("Number 2")
plt.plot(spectrum, p1)

plt.figure("4")
plt.title("Number 4")
plt.plot(timeList, ifft_fcn)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /Users/abdul/Desktop/Programming/Jupyter Lab/ECE2036.ipynb Cell 9' in <module>
#      <a href='vscode-notebook-cell:/Users/abdul/Desktop/Programming/Jupyter%20Lab/ECE2036.ipynb#ch0000008?line=10'>11</a>         return_list.append(float(line.strip()))
#      <a href='vscode-notebook-cell:/Users/abdul/Desktop/Programming/Jupyter%20Lab/ECE2036.ipynb#ch0000008?line=11'>12</a>     return return_list
# ---> <a href='vscode-notebook-cell:/Users/abdul/Desktop/Programming/Jupyter%20Lab/ECE2036.ipynb#ch0000008?line=13'>14</a> wave = open("waveform.txt", "r")
#      <a href='vscode-notebook-cell:/Users/abdul/Desktop/Programming/Jupyter%20Lab/ECE2036.ipynb#ch0000008?line=14'>15</a> values = read(wave)
#      <a href='vscode-notebook-cell:/Users/abdul/Desktop/Programming/Jupyter%20Lab/ECE2036.ipynb#ch0000008?line=15'>16</a> timeList = [t for t in range(len(values))] # for each item in the list, save 0:n
#
# FileNotFoundError: [Errno 2] No such file or directory: 'waveform.txt'

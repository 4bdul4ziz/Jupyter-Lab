# %%
# Python program to display image in a window

import cv2

img = cv2.imread("/Users/abdul/Desktop/Programming/Jupyter Lab/datasets/animeimage.jpg", cv2.IMREAD_COLOR)

cv2.imshow("image", img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# Python program to explain cv2.imshow() method

import cv2
path = r'/Users/abdul/Desktop/Programming/Jupyter Lab/datasets/animeimage.jpg'

image = cv2.imread(path)

window_name = 'image'


cv2.imshow(window_name, image)

cv2.waitKey(0)

cv2.destroyAllWindows()

# %%
# Python program to explain cv2.imwrite() method

import cv2
import os

image_path = r'/Users/abdul/Desktop/Programming/Jupyter Lab/datasets/animeimage.jpg'
directory = r'/Users/abdul/Desktop/Programming/Jupyter Lab/datasets/'
img = cv2.imread(image_path)
os.chdir(directory)
print("Before saving image:")
print(os.listdir(directory))
filename = 'savedImage.jpg'
cv2.imwrite(filename, img)
print("After saving image:")
print(os.listdir(directory))

print('Successfully saved')
# Out:
# Before saving image:
# ['pi5.csv', 'pi3.xlsx', 'linear regression.xlsx', 'adult.csv', 'lreg.xlsx', 'ws.csv', 'pi2.xlsx', 'linear-regression.csv', 'heart.csv', 'pi4.xlsx', 'eighthr.data', 'onehr.data', 'animeimage.jpg', 'linReg.xlsx', 'stu.csv', 'results.csv']
# After saving image:
# ['pi5.csv', 'pi3.xlsx', 'linear regression.xlsx', 'adult.csv', 'lreg.xlsx', 'ws.csv', 'pi2.xlsx', 'linear-regression.csv', 'heart.csv', 'pi4.xlsx', 'eighthr.data', 'onehr.data', 'animeimage.jpg', 'linReg.xlsx', 'savedImage.jpg', 'stu.csv', 'results.csv']
# Successfully saved

# %%
import cv2

image = cv2.imread('/Users/abdul/Desktop/Programming/Jupyter Lab/datasets/animeimage.jpg')
B, G, R = cv2.split(image)
# Corresponding channels are separated

cv2.imshow("original", image)
cv2.waitKey(0)

cv2.imshow("blue", B)
cv2.waitKey(0)

cv2.imshow("Green", G)
cv2.waitKey(0)

cv2.imshow("red", R)
cv2.waitKey(0)

cv2.destroyAllWindows()

# %%
# Python program to illustrate
# arithmetic operation of
# addition of two images

import cv2
import numpy as np

image1 = cv2.imread('/Users/abdul/Desktop/Programming/Jupyter Lab/datasets/image1.jpg')
image2 = cv2.imread('/Users/abdul/Desktop/Programming/Jupyter Lab/datasets/image2.jpg')

weightedSum = cv2.addWeighted(image1, 0.5, image2, 0.4, 0)

cv2.imshow('Weighted Image', weightedSum)

if cv2.waitKey(0) & 0xff == 27:
	cv2.destroyAllWindows()

# %%
# Python program to illustrate
# arithmetic operation of
# subtraction of pixels of two images

import cv2
import numpy as np

image1 = cv2.imread('/Users/abdul/Desktop/Programming/Jupyter Lab/datasets/image1.jpg')
image2 = cv2.imread('/Users/abdul/Desktop/Programming/Jupyter Lab/datasets/image2.jpg')

sub = cv2.subtract(image1, image2)

cv2.imshow('Subtracted Image', sub)

if cv2.waitKey(0) & 0xff == 27:
	cv2.destroyAllWindows()

# %%
# Python program to illustrate
# arithmetic operation of
# bitwise AND of two images
import cv2
import numpy as np

img1 = cv2.imread('/Users/abdul/Desktop/Programming/Jupyter Lab/datasets/image1.jpg')
img2 = cv2.imread('/Users/abdul/Desktop/Programming/Jupyter Lab/datasets/image2.jpg')

dest_and = cv2.bitwise_and(img2, img1, mask=None)

cv2.imshow('Bitwise And', dest_and)

if cv2.waitKey(0) & 0xff == 27:
	cv2.destroyAllWindows()

# %%
# Python program to illustrate
# arithmetic operation of
# bitwise OR of two images

# organizing imports
import cv2
import numpy as np


img1 = cv2.imread('/Users/abdul/Desktop/Programming/Jupyter Lab/datasets/image1.jpg')
img2 = cv2.imread('/Users/abdul/Desktop/Programming/Jupyter Lab/datasets/image2.jpg')

dest_or = cv2.bitwise_or(img2, img1, mask=None)

cv2.imshow('Bitwise OR', dest_or)

if cv2.waitKey(0) & 0xff == 27:
	cv2.destroyAllWindows()

# %%
# Python program to illustrate
# arithmetic operation of
# bitwise XOR of two images

# organizing imports
import cv2
import numpy as np


img1 = cv2.imread('/Users/abdul/Desktop/Programming/Jupyter Lab/datasets/image1.jpg')
img2 = cv2.imread('/Users/abdul/Desktop/Programming/Jupyter Lab/datasets/image2.jpg')

dest_xor = cv2.bitwise_xor(img1, img2, mask=None)

cv2.imshow('Bitwise XOR', dest_xor)

if cv2.waitKey(0) & 0xff == 27:
	cv2.destroyAllWindows()

# %%
# Python program to illustrate
# arithmetic operation of
# bitwise NOT on input image

# organizing imports
import cv2
import numpy as np

img1 = cv2.imread('/Users/abdul/Desktop/Programming/Jupyter Lab/datasets/image1.jpg')
img2 = cv2.imread('/Users/abdul/Desktop/Programming/Jupyter Lab/datasets/image2.jpg')

dest_not1 = cv2.bitwise_not(img1, mask=None)
dest_not2 = cv2.bitwise_not(img2, mask=None)
cv2.imshow('Bitwise NOT on image 1', dest_not1)
cv2.imshow('Bitwise NOT on image 2', dest_not2)

if cv2.waitKey(0) & 0xff == 27:
	cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

image = cv2.imread('/Users/abdul/Desktop/Programming/Jupyter Lab/datasets/animeimage.jpg')
# Loading the image

half = cv2.resize(image, (0, 0), fx=0.1, fy=0.1)
bigger = cv2.resize(image, (1050, 1610))

stretch_near = cv2.resize(image, (780, 540),
                          interpolation=cv2.INTER_NEAREST)


Titles = ["Original", "Half", "Bigger", "Interpolation Nearest"]
images = [image, half, bigger, stretch_near]
count = 4

for i in range(count):
	plt.subplot(2, 2, i + 1)
	plt.title(Titles[i])
	plt.imshow(images[i])

plt.show()

# %%
# Python program to demonstrate erosion and
# dilation of images.
import cv2
import numpy as np

# Reading the input image
img = cv2.imread('/Users/abdul/Desktop/Programming/Jupyter Lab/datasets/animeimage.jpg', 0)

# Taking a matrix of size 5 as the kernel
kernel = np.ones((5, 5), np.uint8)

# The first parameter is the original image,
# kernel is the matrix with which image is
# convolved and third parameter is the number
# of iterations, which will determine how much
# you want to erode/dilate a given image.
img_erosion = cv2.erode(img, kernel, iterations=1)
img_dilation = cv2.dilate(img, kernel, iterations=1)

cv2.imshow('Input', img)
cv2.imshow('Erosion', img_erosion)
cv2.imshow('Dilation', img_dilation)

cv2.waitKey(0)

# %%
# importing libraries
import cv2
import numpy as np

image = cv2.imread('/Users/abdul/Desktop/Programming/Jupyter Lab/datasets/animeimage.jpg')

cv2.imshow('Original Image', image)
cv2.waitKey(0)

# Gaussian Blur
Gaussian = cv2.GaussianBlur(image, (7, 7), 0)
cv2.imshow('Gaussian Blurring', Gaussian)
cv2.waitKey(0)

# Median Blur
median = cv2.medianBlur(image, 5)
cv2.imshow('Median Blurring', median)
cv2.waitKey(0)


# Bilateral Blur
bilateral = cv2.bilateralFilter(image, 9, 75, 75)
cv2.imshow('Bilateral Blurring', bilateral)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# Python program to explain cv2.copyMakeBorder() method
from matplotlib import pyplot as plt
import cv2
# %matplotlib inline

# Reading an image in default mode
image = cv2.imread('/Users/abdul/Desktop/Programming/Jupyter Lab/datasets/animeimage.jpg')

# Using cv2.copyMakeBorder() method
image = cv2.copyMakeBorder(image, 5, 5, 5, 5, cv2.BORDER_CONSTANT, None, value = 0)
plt.imshow(image)
plt.show()

# %%
# import opencv
import cv2

# Load the input image
image = cv2.imread(
    '/Users/abdul/Desktop/Programming/Jupyter Lab/datasets/animeimage.jpg')
cv2.imshow('Original', image)
cv2.waitKey(0)

# Use the cvtColor() function to grayscale the image
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

cv2.imshow('Grayscale', gray_image)
cv2.waitKey(0)

# Window shown waits for any key pressing event
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt


FILE_NAME = 'datasets/animeimage.jpg'
try:
	# Read image from disk.
	img = cv2.imread(FILE_NAME)

	(height, width) = img.shape[:2]

	res = cv2.resize(img, (int(width / 2), int(height / 2)),
	                 interpolation=cv2.INTER_CUBIC)

	# Write image back to disk.
	plt.imshow(res)
	cv2.imwrite('result.jpg', res)

except IOError:
	print('Error while reading files !!!')

# %%
import cv2
import numpy as np

FILE_NAME = 'datasets/animeimage.jpg'
try:
	# Read image from the disk.
	img = cv2.imread(FILE_NAME)

	# Shape of image in terms of pixels.
	(rows, cols) = img.shape[:2]

	# getRotationMatrix2D creates a matrix needed for transformation.
	# We want matrix for rotation w.r.t center to 45 degree without scaling.
	M = cv2.getRotationMatrix2D((cols / 2, rows / 2), 45, 1)
	res = cv2.warpAffine(img, M, (cols, rows))

	# Write image back to disk.
	plt.imshow(res)

	cv2.imwrite('result.jpg', res)
except IOError:
	print('Error while reading files !!!')

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt


FILE_NAME = 'datasets/animeimage.jpg'
# Create translation matrix.
# If the shift is (x, y) then matrix would be
# M = [1 0 x]
#	 [0 1 y]
# Let's shift by (100, 50).
M = np.float32([[1, 0, 100], [0, 1, 50]])

try:

	# Read image from disk.
	img = cv2.imread(FILE_NAME)
	(rows, cols) = img.shape[:2]

	res = cv2.warpAffine(img, M, (cols, rows))

	# Write image back to disk.
	cv2.imwrite('result.jpg', res)
	plt.imshow(res)
except IOError:
	print('Error while reading files !!!')

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
FILE_NAME = 'datasets/animeimage.jpg'
try:
	# Read image from disk.
	img = cv2.imread(FILE_NAME)

	# Canny edge detection.
	edges = cv2.Canny(img, 100, 200)

	# Write image back to disk.
	cv2.imwrite('result.jpg', edges)
	plt.imshow(edges)
except IOError:
	print('Error while reading files !!!')

# %%
# importing required libraries of opencv
import cv2

# importing library for plotting
from matplotlib import pyplot as plt

# reads an input image
img = cv2.imread('datasets/animeimage.jpg', 0)

# find frequency of pixels in range 0-255
histr = cv2.calcHist([img], [0], None, [256], [0, 256])

# show the plotting graph of an image
plt.plot(histr)
plt.show()

# %%
# import Opencv
import cv2

# import Numpy
import numpy as np

# read a image using imread
img = cv2.imread('datasets/animeimage.jpg', 0)

# creating a Histograms Equalization
# of a image using cv2.equalizeHist()
equ = cv2.equalizeHist(img)

# stacking images side-by-side
res = np.hstack((img, equ))

# show image input vs output
cv2.imshow('image', res)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# Python program to illustrate
# simple thresholding type on an image

# organizing imports
import cv2
import numpy as np

# path to input image is specified and
# image is loaded with imread command
image1 = cv2.imread('datasets/animeimage.jpg')

# cv2.cvtColor is applied over the
# image input with applied parameters
# to convert the image in grayscale
img = cv2.cvtColor(image1, cv2.COLOR_BGR2GRAY)

# applying different thresholding
# techniques on the input image
# all pixels value above 120 will
# be set to 255
ret, thresh1 = cv2.threshold(img, 120, 255, cv2.THRESH_BINARY)
ret, thresh2 = cv2.threshold(img, 120, 255, cv2.THRESH_BINARY_INV)
ret, thresh3 = cv2.threshold(img, 120, 255, cv2.THRESH_TRUNC)
ret, thresh4 = cv2.threshold(img, 120, 255, cv2.THRESH_TOZERO)
ret, thresh5 = cv2.threshold(img, 120, 255, cv2.THRESH_TOZERO_INV)

# the window showing output images
# with the corresponding thresholding
# techniques applied to the input images
cv2.imshow('Binary Threshold', thresh1)
cv2.imshow('Binary Threshold Inverted', thresh2)
cv2.imshow('Truncated Threshold', thresh3)
cv2.imshow('Set to 0', thresh4)
cv2.imshow('Set to 0 Inverted', thresh5)

# De-allocate any associated memory usage
if cv2.waitKey(0) & 0xff == 27:
	cv2.destroyAllWindows()

# %%
# Python program to illustrate
# adaptive thresholding type on an image

# organizing imports
import cv2
import numpy as np

# path to input image is specified and
# image is loaded with imread command
image1 = cv2.imread('datasets/animeimage.jpg')

# cv2.cvtColor is applied over the
# image input with applied parameters
# to convert the image in grayscale
img = cv2.cvtColor(image1, cv2.COLOR_BGR2GRAY)

# applying different thresholding
# techniques on the input image
thresh1 = cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_MEAN_C,
                                cv2.THRESH_BINARY, 199, 5)

thresh2 = cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C,
                                cv2.THRESH_BINARY, 199, 5)

# the window showing output images
# with the corresponding thresholding
# techniques applied to the input image
cv2.imshow('Adaptive Mean', thresh1)
cv2.imshow('Adaptive Gaussian', thresh2)


# De-allocate any associated memory usage
if cv2.waitKey(0) & 0xff == 27:
	cv2.destroyAllWindows()

# %%
# Python program to illustrate
# Otsu thresholding type on an image

# organizing imports
import cv2
import numpy as np

# path to input image is specified and
# image is loaded with imread command
image1 = cv2.imread('datasets/animeimage.jpg')

# cv2.cvtColor is applied over the
# image input with applied parameters
# to convert the image in grayscale
img = cv2.cvtColor(image1, cv2.COLOR_BGR2GRAY)

# applying Otsu thresholding
# as an extra flag in binary
# thresholding
ret, thresh1 = cv2.threshold(img, 120, 255, cv2.THRESH_BINARY +
                             cv2.THRESH_OTSU)

# the window showing output image
# with the corresponding thresholding
# techniques applied to the input image
cv2.imshow('Otsu Threshold', thresh1)

# De-allocate any associated memory usage
if cv2.waitKey(0) & 0xff == 27:
	cv2.destroyAllWindows()

# %%
# Python program to explain cv2.cvtColor() method

# importing cv2
import cv2
from matplotlib import pyplot as plt

# path
path = r'datasets/animeimage.jpg'

# Reading an image in default mode
src = cv2.imread(path)

# Using cv2.cvtColor() method
# Using cv2.COLOR_BGR2GRAY color space
# conversion code
image = cv2.cvtColor(src, cv2.COLOR_BGR2GRAY)
plt.imshow(image)
image.splitlines()"hasattr"

# %%
import cv2
import numpy as np
cap = cv2.VideoCapture(0)

while(1):
	_, frame = cap.read()
	# It converts the BGR color space of image to HSV color space
	hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)

	# Threshold of blue in HSV space
	lower_blue = np.array([60, 35, 140])
	upper_blue = np.array([180, 255, 255])

	# preparing the mask to overlay
	mask = cv2.inRange(hsv, lower_blue, upper_blue)

	# The black region in the mask has the value of 0,
	# so when multiplied with original image removes all non-blue regions
	result = cv2.bitwise_and(frame, frame, mask=mask)

	cv2.imshow('frame', frame)
	cv2.imshow('mask', mask)
	cv2.imshow('result', result)

	cv2.waitKey(0)

cv2.destroyAllWindows()
cap.release()

# %%
# importing libraries
import numpy as np
import cv2
from matplotlib import pyplot as plt

# Reading image from folder where it is stored
img = cv2.imread('datasets/animeimage.jpg')

# denoising of image saving it into dst image
dst = cv2.fastNlMeansDenoisingColored(img, None, 10, 10, 7, 15)

# Plotting of source and destination image
plt.subplot(121), plt.imshow(img)
plt.subplot(122), plt.imshow(dst)

plt.show()

# %%
# Python code to find the co-ordinates of
# the contours detected in an image.
import numpy as np
import cv2

# Reading image
font = cv2.FONT_HERSHEY_COMPLEX
img2 = cv2.imread('datasets/img1.jpg', cv2.IMREAD_COLOR)

# Reading same image in another
# variable and converting to gray scale.
img = cv2.imread('datasets/img2.png', cv2.IMREAD_GRAYSCALE)

# Converting image to a binary image
# ( black and white only image).
_, threshold = cv2.threshold(img, 110, 255, cv2.THRESH_BINARY)

# Detecting contours in image.
contours, _= cv2.findContours(threshold, cv2.RETR_TREE,
							cv2.CHAIN_APPROX_SIMPLE)

# Going through every contours found in the image.
for cnt in contours :

	approx = cv2.approxPolyDP(cnt, 0.009 * cv2.arcLength(cnt, True), True)

	# draws boundary of contours.
	cv2.drawContours(img2, [approx], 0, (0, 0, 255), 5)

	# Used to flatted the array containing
	# the co-ordinates of the vertices.
	n = approx.ravel()
	i = 0

	for j in n :
		if(i % 2 == 0):
			x = n[i]
			y = n[i + 1]

			# String containing the co-ordinates.
			string = str(x) + " " + str(y)

			if(i == 0):
				# text on topmost co-ordinate.
				cv2.putText(img2, "Arrow tip", (x, y),
								font, 0.5, (255, 0, 0))
			else:
				# text on remaining co-ordinates.
				cv2.putText(img2, string, (x, y),
						font, 0.5, (0, 255, 0))
		i = i + 1

# Showing the final image.
cv2.imshow('image2', img2)

# Exiting the window if 'q' is pressed on the keyboard.
if cv2.waitKey(0) & 0xFF == ord('q'):
	cv2.destroyAllWindows()

# %%
import cv2
from matplotlib import pyplot as plt

# Read the image.
img = cv2.imread('datasets/animecity.jpg')

# Apply bilateral filter with d = 15,
# sigmaColor = sigmaSpace = 75.
bilateral = cv2.bilateralFilter(img, 15, 75, 75)

# Save the output.
cv2.imwrite('animecity_bilateral.jpg', bilateral)
plt.imshow(bilateral)

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
# Open the image.
img = cv2.imread('datasets/img1.jpg')

# Load the mask.
mask = cv2.imread('datasets/img2.png', 0)

# Inpaint.
dst = cv2.inpaint(img, mask, 3, cv2.INPAINT_NS)

# Write the output.
cv2.imwrite('yes.png', dst)
plt.imshow(dst)

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# Open the image.
img = cv2.imread('datasets/animecity.jpg')

# Apply log transform.
c = 255/(np.log(1 + np.max(img)))
log_transformed = c * np.log(1 + img)

# Specify the data type.
log_transformed = np.array(log_transformed, dtype=np.uint8)

# Save the output.
cv2.imwrite('log_transformed.jpg', log_transformed)
plt.imshow(log_transformed)
# Out:
# /var/folders/kh/vjrj1xvj5jd2tsy0w3350xzw0000gn/T/ipykernel_63343/424496028.py:10: RuntimeWarning: divide by zero encountered in log
#   log_transformed = c * np.log(1 + img)

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# Open the image.
img = cv2.imread('datasets/animecity.jpg')

# Trying 4 gamma values.
for gamma in [0.1, 0.5, 1.2, 2.2]:

	# Apply gamma correction.
	gamma_corrected = np.array(255*(img / 255) ** gamma, dtype='uint8')

	# Save edited images.
	cv2.imwrite('gamma_transformed'+str(gamma)+'.jpg', gamma_corrected)
	plt.imshow(gamma_corrected)

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

def pixelVal(pix, r1, s1, r2, s2):
	if (0 <= pix and pix <= r1):
		return (s1 / r1)*pix
	elif (r1 < pix and pix <= r2):
		return ((s2 - s1)/(r2 - r1)) * (pix - r1) + s1
	else:
		return ((255 - s2)/(255 - r2)) * (pix - r2) + s2

img = cv2.imread('datasets/animecity.jpg')

r1 = 70
s1 = 0
r2 = 140
s2 = 255

pixelVal_vec = np.vectorize(pixelVal)
contrast_stretched = pixelVal_vec(img, r1, s1, r2, s2)
cv2.imwrite('contrast_stretch.jpg', contrast_stretched)
plt.imshow(contrast_stretched)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# Python code for Background subtraction using OpenCV
import numpy as np
import cv2

cap = cv2.VideoCapture(
	'/Users/abdul/Desktop/Programming/Jupyter Lab/datasets/video.mp4')
fgbg = cv2.createBackgroundSubtractorMOG2()

while(1):
	ret, frame = cap.read()

	fgmask = fgbg.apply(frame)

	cv2.imshow('fgmask', fgmask)
	cv2.imshow('frame', frame)

	k = cv2.waitKey(30) & 0xff
	if k == 27:
		break


cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# /Users/abdul/Desktop/Programming/Jupyter Lab/robotVision.ipynb Cell 34 in <module>
#      <a href='vscode-notebook-cell:/Users/abdul/Desktop/Programming/Jupyter%20Lab/robotVision.ipynb#ch0000035?line=9'>10</a> ret, frame = cap.read()
#      <a href='vscode-notebook-cell:/Users/abdul/Desktop/Programming/Jupyter%20Lab/robotVision.ipynb#ch0000035?line=11'>12</a> fgmask = fgbg.apply(frame)
# ---> <a href='vscode-notebook-cell:/Users/abdul/Desktop/Programming/Jupyter%20Lab/robotVision.ipynb#ch0000035?line=13'>14</a> cv2.imshow('fgmask', fgmask)
#      <a href='vscode-notebook-cell:/Users/abdul/Desktop/Programming/Jupyter%20Lab/robotVision.ipynb#ch0000035?line=14'>15</a> cv2.imshow('frame', frame)
# ...

# %%
#Logarithmic
import cv2
import numpy as np
from matplotlib import pyplot as plt
img = cv2.imread('datasets/eclipse_HD.png')
c = 255/(np.log(1 + np.max(img)))
log_transformed = c * np.log(1 + img)
log_transformed = np.array(log_transformed, dtype=np.uint8)
cv2.imwrite('log_transformed.jpg', log_transformed)
plt.imshow(log_transformed)
# Out:
# /var/folders/kh/vjrj1xvj5jd2tsy0w3350xzw0000gn/T/ipykernel_69327/3648894703.py:7: RuntimeWarning: divide by zero encountered in log
#   log_transformed = c * np.log(1 + img)
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Python program to illustrate
# foreground extraction using
# GrabCut algorithm

import numpy as np
import cv2
from matplotlib import pyplot as plt

image = cv2.imread('datasets/animecity.jpg')
mask = np.zeros(image.shape[:2], np.uint8)
backgroundModel = np.zeros((1, 65), np.float64)
foregroundModel = np.zeros((1, 65), np.float64)

rectangle = (20, 100, 150, 150)

cv2.grabCut(image, mask, rectangle,
            backgroundModel, foregroundModel,
            3, cv2.GC_INIT_WITH_RECT)
mask2 = np.where((mask == 2) | (mask == 0), 0, 1).astype('uint8')
image = image * mask2[:, :, np.newaxis]
plt.imshow(image)
plt.colorbar()
plt.show()

# %%
# Python program to illustrate
# Opening morphological operation
# on an image

import cv2
import numpy as np

screenRead = cv2.VideoCapture(0)

while(1):
	_, image = screenRead.read()
	hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

	blue1 = np.array([110, 50, 50])
	blue2 = np.array([130, 255, 255])

	mask = cv2.inRange(hsv, blue1, blue2)

	res = cv2.bitwise_and(image, image, mask=mask)
	kernel = np.ones((5, 5), np.uint8)

	opening = cv2.morphologyEx(mask, cv2.MORPH_OPEN, kernel)
	cv2.imshow('Mask', mask)
	cv2.imshow('Opening', opening)

	if cv2.waitKey(1) & 0xFF == ord('a'):
		break

cv2.destroyAllWindows()

screenRead.release()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/abdul/Desktop/Programming/Jupyter Lab/robotVision.ipynb Cell 37 in <module>
#       <a href='vscode-notebook-cell:/Users/abdul/Desktop/Programming/Jupyter%20Lab/robotVision.ipynb#ch0000037?line=7'>8</a> screenRead = cv2.VideoCapture(0)
#      <a href='vscode-notebook-cell:/Users/abdul/Desktop/Programming/Jupyter%20Lab/robotVision.ipynb#ch0000037?line=9'>10</a> while(1):
# ---> <a href='vscode-notebook-cell:/Users/abdul/Desktop/Programming/Jupyter%20Lab/robotVision.ipynb#ch0000037?line=10'>11</a> 	_, image = screenRead.read()
#      <a href='vscode-notebook-cell:/Users/abdul/Desktop/Programming/Jupyter%20Lab/robotVision.ipynb#ch0000037?line=11'>12</a> 	hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
# ...

# %%
import cv2
import numpy as np

image = cv2.imread('datasets/animecity.jpg')

# Store height and width of the image
height, width = image.shape[:2]

quarter_height, quarter_width = height / 4, width / 4

T = np.float32([[1, 0, quarter_width], [0, 1, quarter_height]])

# We use warpAffine to transform
# the image using the matrix, T
img_translation = cv2.warpAffine(image, T, (width, height))

cv2.imshow("Originalimage", image)
cv2.imshow('Translation', img_translation)
cv2.waitKey()

cv2.destroyAllWindows()

# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.imread("datasets/animecity.jpg")

layer = img.copy()

for i in range(4):
	plt.subplot(2, 2, i + 1)

	# using pyrDown() function
	layer = cv2.pyrDown(layer)

	plt.imshow(layer)
	cv2.imshow("str(i)", layer)
	cv2.waitKey(0)


cv2.destroyAllWindows()
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
img1_color = cv2.imread("datasets/sahil.jpg")
img2_color = cv2.imread("datasets/sahil2.jpg")
img1 = cv2.cvtColor(img1_color, cv2.COLOR_BGR2GRAY)
img2 = cv2.cvtColor(img2_color, cv2.COLOR_BGR2GRAY)
height, width = img2.shape
orb_detector = cv2.ORB_create(5000)
kp1, d1 = orb_detector.detectAndCompute(img1, None)
kp2, d2 = orb_detector.detectAndCompute(img2, None)
matcher = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)
matches = matcher.match(d1, d2)
matches.sort(key=lambda x: x.distance)
matches = matches[:int(len(matches)*0.9)]
no_of_matches = len(matches)
p1 = np.zeros((no_of_matches, 2))
p2 = np.zeros((no_of_matches, 2))

for i in range(len(matches)):
    p1[i, :] = kp1[matches[i].queryIdx].pt
    p2[i, :] = kp2[matches[i].trainIdx].pt
homography, mask = cv2.findHomography(p1, p2, cv2.RANSAC)
transformed_img = cv2.warpPerspective(img1_color, homography, (width, height))
cv2.imwrite('output_sahil_image.jpg', transformed_img)
plt.imshow('transformed_img')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/abdul/Desktop/Programming/Jupyter Lab/robotVision.ipynb Cell 40 in <module>
#      <a href='vscode-notebook-cell:/Users/abdul/Desktop/Programming/Jupyter%20Lab/robotVision.ipynb#ch0000040?line=22'>23</a> transformed_img = cv2.warpPerspective(img1_color, homography, (width, height))
#      <a href='vscode-notebook-cell:/Users/abdul/Desktop/Programming/Jupyter%20Lab/robotVision.ipynb#ch0000040?line=23'>24</a> cv2.imwrite('output_sahil_image.jpg', transformed_img)
# ---> <a href='vscode-notebook-cell:/Users/abdul/Desktop/Programming/Jupyter%20Lab/robotVision.ipynb#ch0000040?line=24'>25</a> plt.imshow('transformed_img')
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/_api/deprecation.py:456, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
# ...

# %%
# Python program to illustrate
# Background subtraction using
# concept of Running Averages

# organize imports
import cv2
import numpy as np

# capture frames from a camera
cap = cv2.VideoCapture(0)

# read the frames from the camera
_, img = cap.read()

# modify the data type
# setting to 32-bit floating point
averageValue1 = np.float32(img)

# loop runs if capturing has been initialized.
while(1):
	# reads frames from a camera
	_, img = cap.read()

	# using the cv2.accumulateWeighted() function
	# that updates the running average
	cv2.accumulateWeighted(img, averageValue1, 0.02)

	# converting the matrix elements to absolute values
	# and converting the result to 8-bit.
	resultingFrames1 = cv2.convertScaleAbs(averageValue1)

	# Show two output windows
	# the input / original frames window
	cv2.imshow('InputWindow', img)

	# the window showing output of alpha value 0.02
	cv2.imshow('averageValue1', resultingFrames1)

	# Wait for Esc key to stop the program
	k = cv2.waitKey(30) & 0xff
	if k == 27:
		break

# Close the window
cap.release()

# De-allocate any associated memory usage
cv2.destroyAllWindows()
# Out:
# Located char match from search: item 'Quit Python' in menu '' with match penalty 0
# Choosing result from list: item 'Quit Python' in menu '' with match penalty 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/abdul/Desktop/Programming/Jupyter Lab/robotVision.ipynb Cell 41 in <module>
#      <a href='vscode-notebook-cell:/Users/abdul/Desktop/Programming/Jupyter%20Lab/robotVision.ipynb#ch0000040?line=36'>37</a> cv2.imshow('averageValue1', resultingFrames1)
#      <a href='vscode-notebook-cell:/Users/abdul/Desktop/Programming/Jupyter%20Lab/robotVision.ipynb#ch0000040?line=38'>39</a> # Wait for Esc key to stop the program
# ---> <a href='vscode-notebook-cell:/Users/abdul/Desktop/Programming/Jupyter%20Lab/robotVision.ipynb#ch0000040?line=39'>40</a> k = cv2.waitKey(30) & 0xff
# ...

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

image = cv2.imread('datasets/animecity.jpg')
#convert to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
#image enhancement by adding a constant value ‘90’ to first half of the image
gray[:gray.shape[0]//2] += 90
#display size and memory before and after the operations
print("Size of the image before enhancement: ", image.shape)
print("Size of the image after enhancement: ", gray.shape)
print("Memory size of the image before enhancement: ", image.size)
print("Memory size of the image after enhancement: ", gray.size)
#display the two images in the same plot
plt.subplot(121),plt.imshow(image),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(gray),plt.title('Enhanced')
plt.xticks([]), plt.yticks([])
plt.show()
# Out:
# Size of the image before enhancement:  (2400, 4800, 3)
# Size of the image after enhancement:  (2400, 4800)
# Memory size of the image before enhancement:  34560000
# Memory size of the image after enhancement:  11520000

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

image = cv2.imread('datasets/animecity.jpg')
#convert to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
#image enhancement by subtracting a constant value ‘90’ to first half of the image
gray[:gray.shape[0]//2] -= 90
#display size and memory before and after the operations
print("Size of the image before enhancement: ", image.shape)
print("Size of the image after enhancement: ", gray.shape)
print("Memory size of the image before enhancement: ", image.size)
print("Memory size of the image after enhancement: ", gray.size)
#display the two images in the same plot
plt.subplot(121),plt.imshow(image),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(gray),plt.title('Enhanced')
plt.xticks([]), plt.yticks([])
plt.show()
# Out:
# Size of the image before enhancement:  (2400, 4800, 3)
# Size of the image after enhancement:  (2400, 4800)
# Memory size of the image before enhancement:  34560000
# Memory size of the image after enhancement:  11520000

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

image = cv2.imread('datasets/animecity.jpg')
#convert to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
#image enhancement like gamma transformation on the entire image
gamma = 0.5
gamma_correction = np.power(gray, gamma) 
#display size and memory before and after the operations
print("Size of the image before enhancement: ", image.shape)
print("Size of the image after enhancement: ", gamma_correction.shape)
print("Memory size of the image before enhancement: ", image.size)
print("Memory size of the image after enhancement: ", gamma_correction.size)
#display the two images in the same plot
plt.subplot(121), plt.imshow(image), plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122), plt.imshow(gamma_correction), plt.title('Enhanced')
plt.xticks([]), plt.yticks([])
plt.show()
# Out:
# Size of the image before enhancement:  (2400, 4800, 3)
# Size of the image after enhancement:  (2400, 4800)
# Memory size of the image before enhancement:  34560000
# Memory size of the image after enhancement:  11520000

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

image = cv2.imread('datasets/animecity.jpg')
#convert to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
#image enhancement by improving the dynamic range of the image
dynamic_range = 100
dynamic_range_correction = gray * (255.0 / dynamic_range)
print("Size of the image before enhancement: ", image.shape)
print("Size of the image after enhancement: ", dynamic_range_correction.shape)
print("Memory size of the image before enhancement: ", image.size)
print("Memory size of the image after enhancement: ", dynamic_range_correction.size)
#display the two images in the same plot
plt.subplot(121), plt.imshow(image), plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122), plt.imshow(dynamic_range_correction), plt.title('Enhanced')
plt.xticks([]), plt.yticks([])
plt.show()
# Out:
# Size of the image before enhancement:  (2400, 4800, 3)
# Size of the image after enhancement:  (2400, 4800)
# Memory size of the image before enhancement:  34560000
# Memory size of the image after enhancement:  11520000
